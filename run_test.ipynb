# %%
import csv
import os
import tqdm
import traceback
import pandas as pd
import numpy as np
import multiprocessing as mp
from psycopg2.errors import UniqueViolation

import rsa_data_summary as rd
import rsa_data_wim as wim
import rsa_headers as rh
import config
import queries as q
import tools

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
partition_table_columns = list(pd.read_sql_query(q.SELECT_PARTITION_TABLE_LIMIT1,config.ENGINE).columns)
electronic_count_data_type_21_columns = list(pd.read_sql_query(q.SELECT_ELECTRONIC_COUNT_DATA_TYPE_21_LIMIT1,config.ENGINE).columns)
electronic_count_data_type_30_columns = list(pd.read_sql_query(q.SELECT_ELECTRONIC_COUNT_DATA_TYPE_30_LIMIT1,config.ENGINE).columns)
electronic_count_data_type_60_columns = list(pd.read_sql_query(q.SELECT_ELECTRONIC_COUNT_DATA_TYPE_60_LIMIT1,config.ENGINE).columns)
electronic_count_data_type_70_columns = list(pd.read_sql_query(q.SELECT_ELECTRONIC_COUNT_DATA_TYPE_70_LIMIT1,config.ENGINE).columns)
electronic_count_data_type_10_columns = list(pd.read_sql_query(q.SELECT_ELECTRONIC_COUNT_DATA_TYPE_10_LIMIT1,config.ENGINE).columns)
header_columns = list(pd.read_sql_query(q.SELECT_HEADER_LIMIT1,config.ENGINE).columns)

# %%
def main(file: str):
    df = tools.to_df(file)
    H = rh.Headers(df, file)
    header = H.header_df
    # print(header)
    # print(header.columns)
    # lanes = H.lanes

    # D = rd.Data(df, header)
    # data = D.dtype21

    # if data is None:
    #     pass
    # else:
    #     d2 = data.copy()
    # if d2 is None:
    #     pass
    # else:
    #     d2.rename(columns=config.ELECTRONIC_COUNT_DATA_TYPE21_NAME_CHANGE, inplace=True)
    #     d2 = d2[d2.columns.intersection(electronic_count_data_type_21_columns)]
    #     try:
    #         d2.to_sql("electronic_count_data_type_21",
    #                 con=config.ENGINE,
    #                 schema="trafc",
    #                 if_exists="append",
    #                 index=False,
    #                 method=tools.psql_insert_copy,
    #             )
    #     except UniqueViolation:
    #         pass

    # d2 = D.dtype70
    # if d2 is None:
    #     pass
    # else:
    #     data = rd.merge_summary_dataframes(d2, data)
    #     d2 = d2[d2.columns.intersection(electronic_count_data_type_70_columns)]
    #     try:
    #         d2.to_sql("electronic_count_data_type_70",
    #             con=config.ENGINE,
    #             schema="trafc",
    #             if_exists="append",
    #             index=False,
    #             method=tools.psql_insert_copy,
    #         )
    #     except UniqueViolation:
    #         pass

    # d2 = D.dtype30
    # if d2 is None:
    #     pass
    # else:
    #     data = rd.merge_summary_dataframes(d2, data)
    
    # d2 = D.electronic_count_data_type_30
    # if d2 is None:
    #     pass
    # else:
    #     try:
    #         d2.to_sql("electronic_count_data_type_30",
    #             con=config.ENGINE,
    #             schema="trafc",
    #             if_exists="append",
    #             index=False,
    #             method=tools.psql_insert_copy,
    #         )
    #     except UniqueViolation:
    #         pass
    

    if header is None:
        pass
    else:
        try:
            # data.reset_index(drop=True, inplace=True)
            # header = header.rename(columns=(lambda x: x[:-2] if '_x' in x else x))
            # header = rd.Data.header_calcs(header, data, 21)
            # header = rd.Data.header_calcs(header, data, 70)
            # header = rd.Data.header_calcs(header, data, 30)
            # header = rd.Data.header_calcs(header, data, 60)
            header = header[header.columns.intersection(header_columns)]
            try:
                header.to_sql("electronic_count_header_test",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
            except UniqueViolation:
                pass
        except AttributeError:
            raise Exception("Issue with HEADER")

    # if data is None:
    #     try:
    #         # main_type10(df, file, header)
    #         pass
    #     except:
    #         pass
    # else:
    #     try:
    #         data = data.rename(columns=(lambda x: x[:-2] if '_x' in x else x))
    #         data = data[data.columns.intersection(partition_table_columns)]
    #         data = data.T.drop_duplicates().T
    #         data.to_sql("electronic_count_data_partitioned",
    #                 con=config.ENGINE,
    #                 schema="trafc",
    #                 if_exists="append",
    #                 index=False,
    #                 method=tools.psql_insert_copy,
    #             )
    #     except UniqueViolation:
    #         pass

    print('DONE WITH '+file)
    with open(
        os.path.expanduser(config.FILES_COMPLETE),
        "a",
        newline="",
    ) as f:
        write = csv.writer(f)
        write.writerows([[file]])

# %%
def main_type10(df: pd.DataFrame, file: str, header: pd.DataFrame):
    WIM = wim.WimData(df, header)
    df, sub_data_df = WIM.dtype10

    if df is None:
        pass
    else:
        try:
            data = data[data.columns.intersection(electronic_count_data_type_10_columns)]
            try:
                tools.push_to_db(df,
                "electronic_count_data_type_10",
                ["site_id", "start_datetime", "assigned_lane_number"],
                )
            except UniqueViolation:
                pass

            sub_data_df = sub_data_df.replace(r'^\s*$', np.NaN, regex=True)
            sub_data_df = sub_data_df.drop("index", axis=1) 
            wx_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 'w']
            sx_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 's']
            gx_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 'g']
            vx_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 'v']
            tx_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 't']
            ax_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 'a']
            cx_data = sub_data_df.loc[sub_data_df['sub_data_type_code'].str.lower().str[0] == 'c']

            if wx_data.empty:
                pass
            else:
                wx_data.rename(columns = {"value":"wheel_mass", "number":"wheel_mass_number", "id":"type10_id"}, inplace=True)
                try:
                    wx_data.to_sql(
                        "traffic_e_type10_wheel_mass",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass

            if ax_data.empty:
                pass
            else:
                ax_data.rename(columns = {"value":"axle_mass", "number":"axle_mass_number", "id":"type10_id"}, inplace=True)
                try:
                    ax_data.to_sql(
                        "traffic_e_type10_axle_mass",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass

            if gx_data.empty:
                pass
            else:
                gx_data.rename(columns = {"value":"axle_group_mass", "number":"axle_group_mass_number", "id":"type10_id"}, inplace=True)
                try:
                    gx_data.to_sql(
                        "traffic_e_type10_axle_group_mass",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass

            if sx_data.empty:
                pass
            else:
                sx_data.rename(columns = {"value":"axle_spacing_cm", "number":"axle_spacing_number", "id":"type10_id"}, inplace=True)
                sx_data = sx_data.drop(["offset_sensor_detection_code","mass_measurement_resolution_kg"], axis=1)
                try:
                    sx_data.to_sql(
                        "traffic_e_type10_axle_spacing",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass

            if tx_data.empty:
                pass
            else:
                tx_data.rename(columns = {"value":"tyre_code", "number":"tyre_number", "id":"type10_id"}, inplace=True)
                tx_data = tx_data.drop(["offset_sensor_detection_code","mass_measurement_resolution_kg"], axis=1)
                try:
                    tx_data.to_sql(
                        "traffic_e_type10_tyre",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass

            if cx_data.empty:
                pass
            else:
                cx_data.rename(columns = {"value":"group_axle_count", "number":"group_axle_number", "id":"type10_id"}, inplace=True)
                cx_data = cx_data.drop(["offset_sensor_detection_code","mass_measurement_resolution_kg"], axis=1)
                try:
                    cx_data.to_sql(
                        "traffic_e_type10_axle_group_configuration",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass

            if vx_data.empty:
                pass
            else:
                vx_data.rename(columns = {"value":"group_axle_count", "offset_sensor_detection_code":"vehicle_registration_number" ,"number":"group_axle_number", "id":"type10_id"}, inplace=True)
                vx_data = vx_data.drop(["mass_measurement_resolution_kg"], axis=1)
                try:
                    vx_data.to_sql(
                        "traffic_e_type10_identification_data_images",
                        con=config.ENGINE,
                        schema="trafc",
                        if_exists="append",
                        index=False,
                        method=tools.psql_insert_copy,
                    )
                except UniqueViolation:
                    pass
            
            with open(
                os.path.expanduser(config.FILES_COMPLETE),
                "a",
                newline="",
            ) as f:
                write = csv.writer(f)
                write.writerows([[file]])
        
        except Exception as e:
            print(e)
            traceback.print_exc()
            with open(
                os.path.expanduser(config.PROBLEM_FILES),
                "a",
                newline="",
            ) as f:
                write = csv.writer(f)
                write.writerows([[file]])
            pass

# %%
PATH = r"C:\FTP\Syntell"
filesToDo = PATH
if tools.is_zip(filesToDo) == False:
    filesToDo = tools.getfiles(filesToDo)
else:
    raise SystemExit
fileComplete = os.path.expanduser(config.FILES_COMPLETE)
try:
    fileComplete = pd.read_csv(fileComplete, header=None)
    fileComplete = fileComplete[0].tolist()
except Exception:
    fileComplete = []

# filesToDo = [i for i in filesToDo if i not in fileComplete]
# Out:
# COLLECTING FILES......

# %%
print(len(filesToDo))
# Out:
# 350

# %%
for file in filesToDo:
    print('---busy with '+ file)
    try:
        main(file)        
    except Exception as e:
        print('check -- '+file)
        print(e)
# Out:
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\1738-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\1738-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0131_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0131_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0141-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0141-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0250_20220615.RSA
# DONE WITH C:\FTP\Syntell\0250_20220615.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0127_20220430.RSA
# DONE WITH C:\FTP\Syntell\0127_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0133-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0133-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0123_20220630.RSA
# DONE WITH C:\FTP\Syntell\0123_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0353_20220430.RSA
# DONE WITH C:\FTP\Syntell\0353_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0108_20220407.RSA
# DONE WITH C:\FTP\Syntell\0108_20220407.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0169_20220430.RSA
# DONE WITH C:\FTP\Syntell\0169_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0095-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0095-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0353_20220331.RSA
# DONE WITH C:\FTP\Syntell\0353_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0123_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0123_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0041_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0041_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0313-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0313-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0141_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0141_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0131_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0131_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0141_20220531.RSA
# DONE WITH C:\FTP\Syntell\0141_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0127-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0127-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0044_20220630.RSA
# DONE WITH C:\FTP\Syntell\0044_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0151_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0151_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0169-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0169-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0263_20220531.RSA
# DONE WITH C:\FTP\Syntell\0263_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0072_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0072_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0108_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0108_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0337_20220430.RSA
# DONE WITH C:\FTP\Syntell\0337_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0041_20220430.RSA
# DONE WITH C:\FTP\Syntell\0041_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0200_20220630.RSA
# DONE WITH C:\FTP\Syntell\0200_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0288_20220331.RSA
# DONE WITH C:\FTP\Syntell\0288_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0151-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0151-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0313_20220331.RSA
# DONE WITH C:\FTP\Syntell\0313_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0123-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0123-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0597_20220227.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0597_20220227.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0095_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0095_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0108-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0108-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0353_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0353_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0009_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0009_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0006_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0006_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0200_20220331.RSA
# DONE WITH C:\FTP\Syntell\0200_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0127_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0127_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0169-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0169-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0700_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0700_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0353-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0353-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0045_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0045_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0700_20220430.RSA
# DONE WITH C:\FTP\Syntell\0700_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0006_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0006_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0009_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0009_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0323_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0323_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0597-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0597-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0288_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0288_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0073_20220630.RSA
# DONE WITH C:\FTP\Syntell\0073_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0073_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0073_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0337_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0337_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0072_20220630.RSA
# DONE WITH C:\FTP\Syntell\0072_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0700_20220331.RSA
# DONE WITH C:\FTP\Syntell\0700_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0041-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0041-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0337_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0337_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0141_20220630.RSA
# DONE WITH C:\FTP\Syntell\0141_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0108_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0108_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0095_20220331.RSA
# DONE WITH C:\FTP\Syntell\0095_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0151_20220630.RSA
# DONE WITH C:\FTP\Syntell\0151_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0597_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0597_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0065_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0065_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0161-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0161-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0400-20220222.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0400-20220222.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0200_20220430.RSA
# DONE WITH C:\FTP\Syntell\0200_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0353_211118155839.RSA
# DONE WITH C:\FTP\Syntell\0353_211118155839.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0700-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0700-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0095-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0095-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0133_20220630.RSA
# DONE WITH C:\FTP\Syntell\0133_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0048-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0048-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0009_20220331.RSA
# DONE WITH C:\FTP\Syntell\0009_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0313_20220430.RSA
# DONE WITH C:\FTP\Syntell\0313_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\1738_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\1738_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0597-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0597-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0006_20220430.RSA
# DONE WITH C:\FTP\Syntell\0006_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0048_20220430.RSA
# DONE WITH C:\FTP\Syntell\0048_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0072_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0072_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0006_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0006_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0169_20220630.RSA
# DONE WITH C:\FTP\Syntell\0169_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0313-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0313-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0095-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0095-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0123_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0123_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0288_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0288_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0048_20220331.RSA
# DONE WITH C:\FTP\Syntell\0048_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0323_20220421.RSA
# DONE WITH C:\FTP\Syntell\0323_20220421.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0045_20220104.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0045_20220104.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0044_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0044_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0350_20220630.RSA
# DONE WITH C:\FTP\Syntell\0350_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0072-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0072-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0048_20220531.RSA
# DONE WITH C:\FTP\Syntell\0048_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0065_20220630.RSA
# DONE WITH C:\FTP\Syntell\0065_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0072-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0072-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0151_20220430.RSA
# DONE WITH C:\FTP\Syntell\0151_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0123-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0123-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0131_20220331.RSA
# DONE WITH C:\FTP\Syntell\0131_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0151_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0151_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0044-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0044-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\1018_211130240000.RSA
# DONE WITH C:\FTP\Syntell\1018_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0169-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0169-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0313_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0313_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0313_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0313_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0353-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0353-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0151_20211231.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0151_20211231.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0072_211130240000.RSA
# DONE WITH C:\FTP\Syntell\0072_211130240000.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0313_20220630.RSA
# DONE WITH C:\FTP\Syntell\0313_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\1738-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\1738-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0006_20220630.RSA
# DONE WITH C:\FTP\Syntell\0006_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0108_20220331.RSA
# DONE WITH C:\FTP\Syntell\0108_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0044_20220331.RSA
# DONE WITH C:\FTP\Syntell\0044_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0169_20220331.RSA
# DONE WITH C:\FTP\Syntell\0169_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0400_20220531.RSA
# DONE WITH C:\FTP\Syntell\0400_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0141-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0141-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0026_20220615.RSA
# DONE WITH C:\FTP\Syntell\0026_20220615.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0350_20220430.RSA
# DONE WITH C:\FTP\Syntell\0350_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0133_20220430.RSA
# DONE WITH C:\FTP\Syntell\0133_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0133_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0133_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0131-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0131-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0323-20220228.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0323-20220228.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0073_20220331.RSA
# DONE WITH C:\FTP\Syntell\0073_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0127_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0127_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0013_20220630.RSA
# DONE WITH C:\FTP\Syntell\0013_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0108_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0108_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0313_20220531.RSA
# DONE WITH C:\FTP\Syntell\0313_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0095_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0095_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0020_20220615.RSA
# DONE WITH C:\FTP\Syntell\0020_20220615.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0337_20220331.RSA
# DONE WITH C:\FTP\Syntell\0337_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0123_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0123_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0350_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0350_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0159_20220615.RSA
# DONE WITH C:\FTP\Syntell\0159_20220615.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0353_20220531.RSA
# DONE WITH C:\FTP\Syntell\0353_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0006_20220531.RSA
# DONE WITH C:\FTP\Syntell\0006_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\1699_20220430.RSA
# DONE WITH C:\FTP\Syntell\1699_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0095_20220430.RSA
# DONE WITH C:\FTP\Syntell\0095_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0127-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0127-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0123_20220430.RSA
# DONE WITH C:\FTP\Syntell\0123_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0041_20220531.RSA
# DONE WITH C:\FTP\Syntell\0041_20220531.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\G014_20220705.RSA
# DONE WITH C:\FTP\Syntell\G014_20220705.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0087_20220630.RSA
# DONE WITH C:\FTP\Syntell\0087_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\1738_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\1738_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0597_20220430.RSA
# DONE WITH C:\FTP\Syntell\0597_20220430.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0041_20220131.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0041_20220131.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\0597_20220331.RSA
# DONE WITH C:\FTP\Syntell\0597_20220331.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0073-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0073-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0169_20220228.RSA
# DONE WITH C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0169_20220228.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0009-20220131.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0009-20220131.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0337-20211231.RSV
# DONE WITH C:\FTP\Syntell\SMEC RSV Files_GP PRM Sites_Dec21toFeb22_individuals\0337-20211231.RSV
# COMPLETE
# ---busy with C:\FTP\Syntell\0095_20220630.RSA
# DONE WITH C:\FTP\Syntell\0095_20220630.RSA
# COMPLETE
# ---busy with C:\FTP\Syntell\SMEC RSA Files_GP PRM Sites_Dec21toFeb22\0353_20220228.RSA
